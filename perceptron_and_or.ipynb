# %% [markdown]
# <a href="https://colab.research.google.com/github/poorjoke2201/ml_lab/blob/main/perceptron_and_or.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Import the Libraries
import numpy as np
from sklearn.linear_model import Perceptron

# %%
X=np.array([
    [0, 0],
    [0, 1],
    [1, 0],
    [1, 1]
])

y_and= np.array([0, 0, 0, 1])
y_or= np.array([0, 1, 1, 1])

# %%
def train_gate(X, y, gate_name):
  model= Perceptron(max_iter=1000, tol=1e-3, random_state=42)
  model.fit(X, y)

  print(f"\n{gate_name} Gate Results: ")
  for i in X:
    pred= model.predict([i])
    print(f"Input: {i}, Output: {pred}")
  print("-"*50)

# %%
# Output for AND Gate
train_gate(X, y_and, "AND")

# Output for OR Gate
train_gate(X, y_or, "OR")
# Out:
# AND Gate Results:
# Input: [0 0], Output: [0]
# Input: [0 1], Output: [0]
# Input: [1 0], Output: [0]
# Input: [1 1], Output: [1]
# --------------------------------------------------
#
# OR Gate Results:
# Input: [0 0], Output: [0]
# Input: [0 1], Output: [1]
# Input: [1 0], Output: [1]
# Input: [1 1], Output: [1]
# --------------------------------------------------
